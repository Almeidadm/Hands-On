# %% [markdown]
# # Evaluation of Models
# Evaluate the accuracy of the implemented from scratch models of supervised learning

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import numpy as np

def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

data = datasets.load_breast_cancer()
X, y = data.data, data.target

y[y == 0] = -1

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=5
)

# %% [markdown]
# ## Naive Bayes

# %%
from models.naivebayes import NaiveBayes

nb = NaiveBayes()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.9385964912280702
# /home/deigo/GIT/Hands-On/Hands-On/IA/scratch/models/naivebayes.py:30: RuntimeWarning: divide by zero encountered in log
#   posterior = np.sum(np.log(self._pdf(idx, x)))

# %% [markdown]
# ## KNN

# %%
from models.knn import KNN

knn = KNN()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.9122807017543859

# %% [markdown]
# ## Decision Tree

# %%
from models.decisiontree import DecisionTree

dt = DecisionTree()
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 4
#       1 from models.decisiontree import DecisionTree
#       3 dt = DecisionTree()
# ----> 4 dt.fit(X_train, y_train)
#       5 y_pred = dt.predict(X_test)
#       6 acc = accuracy(y_test, y_pred)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:36, in DecisionTree.fit(self, X, y)
#      34 def fit(self, X, y) -> None:
#      35     self.n_features = X.shape[1] if not self.n_features else min(X.shape[1], self.n_features)
# ---> 36     self.root = self._grow_tree(X, y)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:48, in DecisionTree._grow_tree(self, X, y, depth)
#      44     return Node(value=leaf_value)
#      46 feat_idxs = np.random.choice(n_feats, self.n_features, replace=False)
# ---> 48 best_feature, best_thresh = self._best_split(X, y, feat_idxs)
#      50 left_idxs, right_idxs = self._split(X[:, best_feature], best_thresh)
#      51 left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth+1)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:65, in DecisionTree._best_split(self, X, y, feat_idxs)
#      62 thresholds = np.unique(X_column)
#      64 for thr in thresholds:
# ---> 65     gain = self._information_gain(y, X_column, thr)
#      67     if gain > best_gain:
#      68         best_gain =  gain
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:74, in DecisionTree._information_gain(self, y, X_column, threshold)
#      73 def _information_gain(self, y, X_column, threshold) -> float:
# ---> 74     parent_entropy = self._entropy(y)
#      76     left_idxs, right_idxs = self._split(X_column, threshold)
#      78     if len(left_idxs) == 0 or len(right_idxs) == 0:
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:95, in DecisionTree._entropy(self, y)
#      94 def _entropy(self, y) -> float:
# ---> 95     hist = np.bincount(y)
#      96     ps = hist / len(y)
#      97     return -np.sum([p * np.log(p) for p in ps if p>0])
#
# ValueError: 'list' argument must have no negative elements

# %% [markdown]
# ## Random Forests

# %%
from models.randomforest import RandomForest

rf = RandomForest()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 4
#       1 from models.randomforest import RandomForest
#       3 rf = RandomForest()
# ----> 4 rf.fit(X_train, y_train)
#       5 y_pred = rf.predict(X_test)
#       6 acc = accuracy(y_test, y_pred)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/randomforest.py:25, in RandomForest.fit(self, X, y)
#      20 tree = DecisionTree(max_depth=self.max_depth,
#      21                     min_samples_split=self.min_sample_split,
#      22                     n_features=self.n_feature
#      23 )
#      24 X_sample, y_sample = self._bootstrap_samples(X, y)
# ---> 25 tree.fit(X_sample, y_sample)
#      26 self.trees.append(tree)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:36, in DecisionTree.fit(self, X, y)
#      34 def fit(self, X, y) -> None:
#      35     self.n_features = X.shape[1] if not self.n_features else min(X.shape[1], self.n_features)
# ---> 36     self.root = self._grow_tree(X, y)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:48, in DecisionTree._grow_tree(self, X, y, depth)
#      44     return Node(value=leaf_value)
#      46 feat_idxs = np.random.choice(n_feats, self.n_features, replace=False)
# ---> 48 best_feature, best_thresh = self._best_split(X, y, feat_idxs)
#      50 left_idxs, right_idxs = self._split(X[:, best_feature], best_thresh)
#      51 left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth+1)
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:65, in DecisionTree._best_split(self, X, y, feat_idxs)
#      62 thresholds = np.unique(X_column)
#      64 for thr in thresholds:
# ---> 65     gain = self._information_gain(y, X_column, thr)
#      67     if gain > best_gain:
#      68         best_gain =  gain
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:74, in DecisionTree._information_gain(self, y, X_column, threshold)
#      73 def _information_gain(self, y, X_column, threshold) -> float:
# ---> 74     parent_entropy = self._entropy(y)
#      76     left_idxs, right_idxs = self._split(X_column, threshold)
#      78     if len(left_idxs) == 0 or len(right_idxs) == 0:
#
# File ~/GIT/Hands-On/Hands-On/IA/scratch/models/decisiontree.py:95, in DecisionTree._entropy(self, y)
#      94 def _entropy(self, y) -> float:
# ---> 95     hist = np.bincount(y)
#      96     ps = hist / len(y)
#      97     return -np.sum([p * np.log(p) for p in ps if p>0])
#
# ValueError: 'list' argument must have no negative elements

# %% [markdown]
# ## Logistic Regression

# %%
from models.logisticregression import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.0
# /home/deigo/GIT/Hands-On/Hands-On/IA/scratch/models/logisticregression.py:4: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-x))

# %% [markdown]
# ## Perceptron

# %%
from models.perceptron import Perceptron

slp = Perceptron()
slp.fit(X_train, y_train)
y_pred = slp.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.5263157894736842

# %% [markdown]
# ## SVM

# %%
from models.svm import SVM

svm = SVM()
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.9122807017543859

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
def visualize_svm():
        def get_hyperplane_value(x, w, b, offset):
            return (-w[0] * x + b + offset) / w[1]

        fig = plt.figure()
        ax = fig.add_subplot(1, 1, 1)
        plt.scatter(X[:, 0], X[:, 1], marker="o", c=y)

        x0_1 = np.amin(X[:, 0])
        x0_2 = np.amax(X[:, 0])

        x1_1 = get_hyperplane_value(x0_1, svm.w, svm.b, 0)
        x1_2 = get_hyperplane_value(x0_2, svm.w, svm.b, 0)

        x1_1_m = get_hyperplane_value(x0_1, svm.w, svm.b, -1)
        x1_2_m = get_hyperplane_value(x0_2, svm.w, svm.b, -1)

        x1_1_p = get_hyperplane_value(x0_1, svm.w, svm.b, 1)
        x1_2_p = get_hyperplane_value(x0_2, svm.w, svm.b, 1)

        ax.plot([x0_1, x0_2], [x1_1, x1_2], "y--")
        ax.plot([x0_1, x0_2], [x1_1_m, x1_2_m], "k")
        ax.plot([x0_1, x0_2], [x1_1_p, x1_2_p], "k")

        x1_min = np.amin(X[:, 1])
        x1_max = np.amax(X[:, 1])
        ax.set_ylim([x1_min - 3, x1_max + 3])

        plt.show()

# %%
visualize_svm()

# %% [markdown]
# ## Adaboost

# %%
from models.adaboost import Adaboost

adab = Adaboost()
adab.fit(X_train, y_train)
y_pred = adab.predict(X_test)
acc = accuracy(y_test, y_pred)
print(f"accuracy: {acc}")
# Out:
# accuracy: 0.9736842105263158
